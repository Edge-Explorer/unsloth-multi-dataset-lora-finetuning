# %%
# !pip install --quiet --upgrade "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --quiet --no-deps "xformers<0.0.35" "trl" peft accelerate bitsandbytes

# %%
# !ls -lh
# Out:
# total 151M
# -rw-r--r-- 1 root root 2.2K Mar  9 13:27  comparison.py
# -rw-r--r-- 1 root root 151M Mar  9 13:30 'lora_model .zip'
# drwxr-xr-x 1 root root 4.0K Feb  6 14:31  sample_data

# %%
# !unzip "lora_model .zip"
# Out:
# Archive:  lora_model .zip
#    creating: lora_model/
#   inflating: lora_model/tokenizer_config.json
#   inflating: lora_model/README.md
#   inflating: lora_model/tokenizer.json
#   inflating: lora_model/adapter_config.json
#   inflating: lora_model/adapter_model.safetensors

# %%
# !python "comparison.py"
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
#
# [1/2] Loading Fine-Tuned Model (LoRA)...
# ==((====))==  Unsloth 2026.3.4: Fast Llama patching. Transformers: 5.2.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.34. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors: 100% 5.70G/5.70G [00:37<00:00, 152MB/s]
# Loading weights: 100% 291/291 [00:21<00:00, 13.76it/s, Materializing param=model.norm.weight]
# generation_config.json: 100% 198/198 [00:00<00:00, 1.22MB/s]
# config.json: 1.25kB [00:00, 4.38MB/s]
# tokenizer_config.json: 50.6kB [00:00, 123MB/s]
# tokenizer.json: 9.09MB [00:00, 109MB/s]
# special_tokens_map.json: 100% 350/350 [00:00<00:00, 954kB/s]
# [2/2] Loading Base Model (Raw Llama-3)...
# ==((====))==  Unsloth 2026.3.4: Fast Llama patching. Transformers: 5.2.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.34. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights: 100% 291/291 [00:12<00:00, 22.62it/s, Materializing param=model.norm.weight]
#
# PROMPT: Explain Rayleigh scattering specifically for the color blue.
# ==================================================
# RAW OUTPUT:
# Rayleigh scattering is the scattering of light by particles much smaller than the wavelength of the light. It is responsible for the blue color of the sky. The blue color is due to the fact that blue light is scattered more than red light. This is because the wavelength of blue light is shorter than the wavelength of red light. The shorter the wavelength, the more the light is scattered. The scattering of light by particles in the atmosphere is also responsible for the reddish color of the setting sun. The sun appears red because the blue light is scattered out of the path of the sun's rays before they reach the observer. The red light is
#
# FINE-TUNED OUTPUT:
# Rayleigh scattering is a type of scattering that occurs when light interacts with small particles in the atmosphere. It is responsible for the color of the sky, as well as the red-orange glow of sunsets and sunrises.
#
# The color of the sky is blue because blue light is scattered more than other colors. This is because blue light has a shorter wavelength than other colors, and shorter wavelengths are more easily scattered. As a result, blue light is scattered more than other colors, and the sky appears blue.
#
# The red-orange glow of sunsets and sunrises is caused by the same principle. As the sun sets, the light from
#
#
# PROMPT: Write a Python function for a binary search algorithm.
# ==================================================
# RAW OUTPUT:
#
#
# FINE-TUNED OUTPUT:
# def binary_search(arr, x):
#     # Find the middle index
#     mid = len(arr) // 2
#
#     # Base case
#     if len(arr) == 0:
#         return False
#
#     # Check if the middle element is the target
#     if arr[mid] == x:
#         return True
#
#     # If the target is less than the middle element, search the left half
#     elif x < arr[mid]:
#         return binary_search(arr[:mid], x)
#
#     # If the target is greater than the middle element, search the right half
#     else:
#         return binary_search(arr[mid+1
#
#
# PROMPT: How do I cook the perfect scrambled eggs?
# ==================================================
# RAW OUTPUT:
# The following code will help you cook the perfect scrambled eggs:
#
#     # Scrambled Eggs
#     import random
#
#     def scrambled_eggs(eggs):
#         """Return scrambled eggs."""
#         scrambled = eggs.split()
#         random.shuffle(scrambled)
#         return''.join(scrambled)
#
#     eggs = input('Enter scrambled eggs: ')
#     print(scrambled_eggs(eggs))
#
# FINE-TUNED OUTPUT:
# To make the perfect scrambled eggs, start by whisking together 2 eggs and 1/4 cup of milk in a bowl. Then, melt some butter in a pan over medium heat and pour the egg mixture into the pan. Stir the eggs gently until they are just set, then remove from heat and season with salt and pepper. Serve immediately. Enjoy!
